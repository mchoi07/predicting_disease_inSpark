# %%
import pandas as pd 

encounter = pd.read_csv('encounter_INPUT.csv')
encounter_dx = pd.read_csv('encounter_INPUT.csv')
lab = pd.read_csv("lab_results_INPUT.csv")
med = pd.read_csv("medication_orders_INPUT.csv")

# %%
med.head()
# Out:
#                       Provider_Org     Member_ID  Last_Filled_Date  \
# 0  ExactData Medical Health System  054460000-01               NaN
# 1  ExactData Medical Health System  093007089-01               NaN
# 2  ExactData Medical Health System  000001950-01               NaN
# 3  ExactData Medical Health System  297920000-01               NaN
# 4  ExactData Medical Health System  000137537-01               NaN
#
#                 Drug_Name      Drug_NDC  Status                         Sig  \
# 0              Lisinopril  0143-1268-10  active              20 MG PO DAILY
# 1  Isotonic Saline (0.9%)  0264-4001-55  active                    per dose
# 2                  OMS 50  65689-001-21  active  via nasal cannula (contin)
# 3              Gentamicin  63323-010-02  active                     IM q 24
# 4                ACTIVASE  50242-044-13  active                          IV
#
#    Route Dose  Units      Order_ID            Order_Date  Qty_Ordered  \
# ...

# %%
lab.head()
# Out:
#                       Provider_Org     Member_ID        Date_Collected  \
# 0  ExactData Medical Health System  000722505-01  2014-09-29T17:30:00Z
# 1  ExactData Medical Health System  000102950-01  2005-04-24T04:52:00Z
# 2  ExactData Medical Health System  953005554-01  2014-10-23T16:07:00Z
# 3  ExactData Medical Health System  421180000-01  2009-03-11T21:12:00Z
# 4  ExactData Medical Health System  000040819-01  2009-06-24T20:26:00Z
#
#               Test_ID  Specialty  Panel Test_LOINC             Test_Name  \
# 0  140929 CH 37805214        NaN  False    28631-0   Visual Acuity Study
# 1  050424 CH 73375176        NaN  False    49135-7                  FENa
# 2  141023 CH 68634270        NaN  False    17856-6                 HbA1c
# 3  090311 CH 50536831        NaN  False    41806-1     Abdominal CT Scan
# 4  090624 CH 25540873        NaN  False    24356-8  Urinalysis, Complete
#
#           Date_Resulted  Specimen          ...                 Result_Name  \
# ...

# %%
encounter_dx.head()
# Out:
#                       Provider_Org          Encounter_ID     Member_ID  \
# 0  ExactData Medical Health System  O8082102551314770612  000140966-01
# 1  ExactData Medical Health System  B9449398922084349889  202009464-01
# 2  ExactData Medical Health System  L6729846209526290671  818009099-01
# 3  ExactData Medical Health System  X6939812739103289666  545360000-01
# 4  ExactData Medical Health System  I3604016182102774507  000012631-01
#
#    Provider_ID  Provider_NPI                    Clinic_ID  \
# 0    240274834    2174608899     Samaritan Medical Center
# 1    686257276    2045687379     Partners in Primary Care
# 2    748777992    2234959357            Joel Wilkerson MD
# 3    982458475    1226278875  Center for Kidney Disorders
# 4    402802412    1997525561     Drs Shepard and Lugerner
#
#      Encounter_DateTime                              Encounter_Description  \
# 0  2008-07-06T05:10:00Z  Elmo visited emergency clinic on 7/6/2008 12:1...
# ...

# %%
encounter.head()
# Out:
#                       Provider_Org          Encounter_ID     Member_ID  \
# 0  ExactData Medical Health System  O8082102551314770612  000140966-01
# 1  ExactData Medical Health System  B9449398922084349889  202009464-01
# 2  ExactData Medical Health System  L6729846209526290671  818009099-01
# 3  ExactData Medical Health System  X6939812739103289666  545360000-01
# 4  ExactData Medical Health System  I3604016182102774507  000012631-01
#
#    Provider_ID  Provider_NPI                    Clinic_ID  \
# 0    240274834    2174608899     Samaritan Medical Center
# 1    686257276    2045687379     Partners in Primary Care
# 2    748777992    2234959357            Joel Wilkerson MD
# 3    982458475    1226278875  Center for Kidney Disorders
# 4    402802412    1997525561     Drs Shepard and Lugerner
#
#      Encounter_DateTime                              Encounter_Description  \
# 0  2008-07-06T05:10:00Z  Elmo visited emergency clinic on 7/6/2008 12:1...
# ...
